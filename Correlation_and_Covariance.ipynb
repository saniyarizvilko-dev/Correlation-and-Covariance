# %% [markdown]
# Q1. Covariance vs Correlation
#
# Covariance measures how two variables move together.
#
# Positive → move in same direction
#
# Negative → move in opposite direction
#
# Difference from Correlation:
#
# Covariance has no fixed scale (depends on units)
#
# Correlation is standardized and lies between –1 and +1
#
# Correlation is easier to interpret
#
# Q2. Interpretation of Covariance
#
# Positive covariance: Both variables increase/decrease together
#
# Negative covariance: One increases while the other decreases
#
# Zero covariance: No linear relationship
#
# Q3. Limitations of Covariance
#
# Depends on units of measurement
#
# Cannot indicate strength of relationship
#
# Difficult to interpret magnitude
#
# Why correlation is preferred:
# Correlation is unit-free, bounded (–1 to +1), and shows strength + direction.
#
# Q4. Pearson vs Spearman Correlation
# Pearson	Spearman
# Measures linear relationship	Measures monotonic relationship
# Uses actual values	Uses ranks
# Sensitive to outliers	Less sensitive
#
# Use Spearman when:
#
# Data is ordinal
#
# Relationship is non-linear
#
# Outliers exist
#
# Q5. Interpretation of r = 0.85
#
# Strong positive correlation
#
# Variables move closely together
#
# Causation?
# ❌ No. Correlation does not imply causation because other factors may influence both variables.
#
# Q6. Covariance between X and Y
# X	2	4	6	8
# Y	3	7	5	10
#
# Mean X = 5
#
# Mean Y = 6.25
#
# Covariance ≈ 6.33
#
# ➡️ Indicates a positive relationship
#
# Q7. Pearson Correlation (A & B)
# A	10	20	30	40	50
# B	8	14	18	24	28
#
# Correlation ≈ +1
#
# ➡️ Almost perfect positive linear relationship
#
# Q8. Height–Weight Correlation
# Height (cm)	150	160	165	170	180
# Weight (kg)	50	55	58	62	70
#
# Correlation ≈ +0.99
#
# Strong positive relationship
# ➡️ Taller students tend to weigh more
#
# Q9. Direction of Correlation (Reasoning Only)
# X	2	4	6	8
# Y	3	7	5	10
#
# As X increases, Y generally increases
# ➡️ Positive correlation
#
# Q10. Portfolio Analysis
# Year	1	2	3	4	5
# Portfolio A	8	6	10	12	9
# Portfolio B	9	11	8	10	11
#
# Covariance: Positive
#
# Correlation: Moderately positive (≈ 0.6)
#
# Interpretation:
# The portfolios generally move together, but not perfectly.
